# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("data/starbucks_uncleaned.xlsx")

# %%
(df.head())
# Out:
#   transaction_id  order_date customer_id               store_name       city  \
# 0       TXN00001  2025-03-31    CUST1055   Starbucks Phoenix Mall     Mumbai
# 1       TXN00002  2025-12-11    CUST1091  Starbucks Koregaon Park       Pune
# 2       TXN00003  2025-02-16    CUST1020      Starbucks Cyber Hub  Bengaluru
# 3       TXN00004  24/01/2026    CUST1142      Starbucks Cyber Hub  Bengaluru
# 4       TXN00005  2026-04-15    CUST1143      Starbucks Mall Road   Ludhiana
#
#             product_name     category  size  quantity unit_price_inr  \
# 0               Iced Tea          Tea   NaN       2.0            245
# 1       Blueberry Muffin       Bakery   NaN       1.0            215
# 2               Espresso       Coffee   NaN       NaN            215
# 3             Cappuccino       Coffee  Tall       1.0            290
# 4  Java Chip Frappuccino  Frappuccino   NaN       NaN            365
#
#    discount_percent total_amount_inr payment_method customer_rating  \
# ...

# %%
df.shape
# Out:
# (548, 16)

# %%
(df.columns)
# Out:
# Index(['transaction_id', 'order_date', 'customer_id', 'store_name', 'city',
#        'product_name', 'category', 'size', 'quantity', 'unit_price_inr',
#        'discount_percent', 'total_amount_inr', 'payment_method',
#        'customer_rating', 'loyalty_member', 'order_channel'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    548 non-null    object
#  1   order_date        506 non-null    object
#  2   customer_id       532 non-null    object
#  3   store_name        548 non-null    object
#  4   city              548 non-null    object
#  5   product_name      548 non-null    object
#  6   category          541 non-null    object
#  7   size              394 non-null    object
#  8   quantity          489 non-null    float64
#  9   unit_price_inr    540 non-null    object
#  10  discount_percent  423 non-null    float64
#  11  total_amount_inr  343 non-null    object
#  12  payment_method    415 non-null    object
#  13  customer_rating   488 non-null    object
#  14  loyalty_member    385 non-null    object
#  15  order_channel     408 non-null    object
# ...
